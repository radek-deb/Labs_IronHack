# %% [markdown]
# # Subsetting and Descriptive Stats
#
# ## Before your start:
#    - Remember that you just need to do one of the challenges.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in IronHack's database.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly: enjoy the process!
#
# #### Import all the necessary libraries here:

# %%
# import libraries here
import pandas as pd 
import numpy as np

# %% [markdown]
# # Challenge 1
# #### In this challenge we will use the `Temp_States`  dataset.
#
# #### First import it into a dataframe called `temp`.

# %%
# your code here
temp=pd.read_csv(r'C:\Users\radek\IronHack\IronRadek\Week5\Day3\Lab_10_Subsetting_and_Descriptive_Statistics\Temp_States.csv')

# %% [markdown]
# #### Print `temp`.

# %%
# your code here
print(temp)
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444
# 5      Treton   New Jersey    22.222222
# 6      Newark   New Jersey    20.000000

# %% [markdown]
# #### Explore the data types of the *temp* dataframe. What types of data do we have? Comment your result.

# %%
# your code here
temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   City         7 non-null      object
#  1   State        7 non-null      object
#  2   Temperature  7 non-null      float64
# dtypes: float64(1), object(2)
# memory usage: 296.0+ bytes

# %%
temp.dtypes
# Out:
# City            object
# State           object
# Temperature    float64
# dtype: object

# %%
"""
I have data in 3 columns two of them are categorical data: City and State
and 1 column is a numerical data (float number): Temperature
"""

# %% [markdown]
# #### Select the rows where state is New York.

# %%
# your code here
temp_NY =temp[temp.State=='New York']
temp_NY
# Out:
#       City     State  Temperature
# 0      NYC  New York    19.444444
# 1   Albany  New York     9.444444
# 2  Buffalo  New York     3.333333

# %% [markdown]
# #### What is the average temperature of cities in New York?

# %%
# your code here
temp_NY.mean()
# Out:
# C:\Users\radek\AppData\Local\Temp/ipykernel_9832/1742416507.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   temp_NY.mean()
# Temperature    10.740741
# dtype: float64

# %%
'''
The average temperature in the cities of New York is equal to 10.7 degrees. 
'''

# %% [markdown]
# #### Which states and cities have a temperature above 15 degrees Celsius?

# %%
# your code here
temp[temp.Temperature > 15]
# Out:
#        City        State  Temperature
# 0       NYC     New York    19.444444
# 3  Hartford  Connecticut    17.222222
# 5    Treton   New Jersey    22.222222
# 6    Newark   New Jersey    20.000000

# %% [markdown]
# #### Now, return only the cities that have a temperature above 15 degrees Celsius.

# %%
# your code here
temp['City'][temp.Temperature > 15]
# Out:
# 0         NYC
# 3    Hartford
# 5      Treton
# 6      Newark
# Name: City, dtype: object

# %% [markdown]
# #### Which cities have a temperature above 15 degrees Celcius and below 20 degrees Celsius?
#
# **Hint**: First, write the condition. Then, select the rows.

# %%
# your code here
temp['City'][(temp.Temperature > 15) & (temp.Temperature <20)]
# Out:
# 0         NYC
# 3    Hartford
# Name: City, dtype: object

# %% [markdown]
# #### Find the mean and standard deviation of the temperature of each state.

# %%
# your code here
temp.groupby('State')['Temperature'].agg(['mean', 'std'] )
# Out:
#                   mean       std
# State
# Connecticut  15.833333  1.964186
# New Jersey   21.111111  1.571348
# New York     10.740741  8.133404

# %% [markdown]
# #  Challenge 2

# %% [markdown]
# #### Load the `employees` dataset into a dataframe. Call the dataframe `employees`.

# %%
# your code here
employees = pd.read_csv(r'C:\Users\radek\IronHack\IronRadek\Week5\Day3\Lab_10_Subsetting_and_Descriptive_Statistics\Employees.csv')

# %% [markdown]
# #### Explore the data types of the `employees` dataframe. Comment your results.

# %%
# your code here
employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Department  500 non-null    object
#  1   Education   500 non-null    object
#  2   Title       500 non-null    object
#  3   Name        500 non-null    object
#  4   Years       500 non-null    int64
#  5   Salary      500 non-null    int64
# dtypes: int64(2), object(4)
# memory usage: 23.6+ KB

# %%
employees.dtypes
# Out:
# Department    object
# Education     object
# Title         object
# Name          object
# Years          int64
# Salary         int64
# dtype: object

# %%
"""
I have data presnted in 6 columns: 
-in 4 of them there are categorical data i.e.: Department, Education, Title, Name
-in 2 of therm there are numerical data i.e.: Years and Salary
"""

# %%
employees.head()
# Out:
#   Department Education      Title      Name  Years  Salary
# 0      Admin    Master  associate     David      4      58
# 1         IT    Master  associate    Thomas      7      45
# 2      Admin    Master  associate     Diana     10      52
# 3      Admin    Master         VP  Manuella     15      33
# 4      Sales    Master    Analyst     Carla      6      38

# %%
employees.shape
# Out:
# (500, 6)

# %% [markdown]
# #### What's the average salary in this company?

# %%
# your code here
#Average salary is equal to:
employees['Salary'].mean()
# Out:
# 73.528

# %% [markdown]
# #### What's the highest salary?

# %%
# your code here
#Max salary is equal to:
employees['Salary'].max()
# Out:
# 120

# %% [markdown]
# #### What's the lowest salary?

# %%
# your code here
#The lowest salary is equal to:
employees['Salary'].min()
# Out:
# 30

# %% [markdown]
# #### Who are the employees with the lowest salary?

# %%
# your code here
#The list of employees with the lowest salary:
employees[employees.Salary ==employees['Salary'].min() ]
# Out:
#     Department Education      Title      Name  Years  Salary
# 27          IT  Bachelor    Analyst      Sean     12      30
# 106      Admin  Bachelor  associate      Luke      4      30
# 128      Sales       PhD         VP      Adam      8      30
# 139      Sales       PhD    Analyst      Rick     11      30
# 214      Sales    Master         VP      Neil     11      30
# 266         HR       PhD  associate    Marcel     10      30
# 452         IT  Bachelor    Analyst  Augustin     13      30

# %% [markdown]
# #### Find all the information about an employee called David.

# %%
# your code here
#There are two employees with that name:
employees[employees.Name =='David']
# Out:
#     Department Education      Title   Name  Years  Salary
# 0        Admin    Master  associate  David      4      58
# 124         IT  Bachelor         VP  David      3      31

# %% [markdown]
# #### Could you return only David's salary?

# %%
# your code here
employees['Salary'][employees.Name =='David']
# Out:
# 0      58
# 124    31
# Name: Salary, dtype: int64

# %% [markdown]
# #### Print all the rows where job title is associate.

# %%
# your code here
employees[employees.Title =='associate']
# Out:
#     Department Education      Title      Name  Years  Salary
# 0        Admin    Master  associate     David      4      58
# 1           IT    Master  associate    Thomas      7      45
# 2        Admin    Master  associate     Diana     10      52
# 7           HR    Master  associate     Carol     14      53
# 8        Admin       PhD  associate      Jean      8      50
# ..         ...       ...        ...       ...    ...     ...
# 477         HR       PhD  associate   Phillip     11     113
# 486         IT  Bachelor  associate       Jay     14      58
# 487         HR    Master  associate  Patricia     10     110
# 491      Admin       PhD  associate     Alice      8      37
# 494      Sales  Bachelor  associate   Vanessa     11     118
#
# [158 rows x 6 columns]

# %% [markdown]
# #### Print the first 3 rows of your dataframe.
# **Tip**: There are 2 ways to do it. Do it both ways.

# %%
# Method 1
# your code here
employees.head(3)
# Out:
#   Department Education      Title    Name  Years  Salary
# 0      Admin    Master  associate   David      4      58
# 1         IT    Master  associate  Thomas      7      45
# 2      Admin    Master  associate   Diana     10      52

# %%
# Method 2
# your code here
employees[0:3]
# Out:
#   Department Education      Title    Name  Years  Salary
# 0      Admin    Master  associate   David      4      58
# 1         IT    Master  associate  Thomas      7      45
# 2      Admin    Master  associate   Diana     10      52

# %% [markdown]
# #### Find the employees whose title is associate and whose salary is above 55.

# %%
# your code here
employees[(employees.Title == 'associate') & (employees.Salary > 55)]
# Out:
#     Department Education      Title      Name  Years  Salary
# 0        Admin    Master  associate     David      4      58
# 9        Admin    Master  associate    Kareem      3     104
# 10       Admin    Master  associate   Cynthia      1     114
# 16       Admin  Bachelor  associate    Shanon      1      99
# 18       Admin  Bachelor  associate     Megan      9      79
# ..         ...       ...        ...       ...    ...     ...
# 476      Admin       PhD  associate      Greg      8      93
# 477         HR       PhD  associate   Phillip     11     113
# 486         IT  Bachelor  associate       Jay     14      58
# 487         HR    Master  associate  Patricia     10     110
# 494      Sales  Bachelor  associate   Vanessa     11     118
#
# [104 rows x 6 columns]

# %% [markdown]
# #### Group the employees by number of years of employment. What are the average salaries in each group?

# %%
# your code here
#List of years and the coresponding average salary
employees.groupby('Years')['Salary'].agg(['mean'])
# Out:
#             mean
# Years
# 1      75.863636
# 2      75.857143
# 3      74.571429
# 4      77.129032
# 5      73.857143
# 6      72.382353
# 7      73.840000
# 8      64.250000
# 9      76.741935
# 10     73.351351
# 11     74.866667
# 12     73.454545
# 13     71.935484
# 14     70.968750
# 15     69.758621

# %% [markdown]
# ####  What is the average salary per title?

# %%
# your code here
employees.groupby('Title')['Salary'].agg(['mean'])
# Out:
#                 mean
# Title
# Analyst    73.703911
# VP         72.907975
# associate  73.968354

# %% [markdown]
# ####  Find the salary quartiles.

# %%
# your code here
#I can do that simply by using describe function
employees.describe()
# Out:
#             Years      Salary
# count  500.000000  500.000000
# mean     7.556000   73.528000
# std      4.465731   26.890061
# min      1.000000   30.000000
# 25%      3.000000   50.000000
# 50%      7.000000   72.000000
# 75%     11.250000   97.000000
# max     15.000000  120.000000

# %%
#The other method is to call quantile method 
employees['Salary'].quantile([0,0.25,0.5,0.75,1])
# Out:
# 0.00     30.0
# 0.25     50.0
# 0.50     72.0
# 0.75     97.0
# 1.00    120.0
# Name: Salary, dtype: float64

# %% [markdown]
# #### Is the mean salary different per gender?

# %%
employees.head()
# Out:
#   Department Education      Title      Name  Years  Salary
# 0      Admin    Master  associate     David      4      58
# 1         IT    Master  associate    Thomas      7      45
# 2      Admin    Master  associate     Diana     10      52
# 3      Admin    Master         VP  Manuella     15      33
# 4      Sales    Master    Analyst     Carla      6      38

# %%
# your code here
'''
As presented in the cell above there is no information on gender in the dataframe. It is probably possible to get that data from the name as for example female names tend to end with letter 'a', but such method is very likly to give result with a lot of mistakes. Therefore it is not possible to say if the mean salary is diffrent per gender.
'''

# %% [markdown]
# #### Find the minimum, mean and maximum of all numeric columns for each company department.

# %%
# your code here
employees.groupby('Department')['Salary','Years'].agg(['mean', 'max', 'min'])
# Out:
# C:\Users\radek\AppData\Local\Temp/ipykernel_9832/787383757.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   employees.groupby('Department')['Salary','Years'].agg(['mean', 'max', 'min'])
#                Salary              Years
#                  mean  max min      mean max min
# Department
# Admin       76.325203  120  30  7.642276  15   1
# HR          74.237705  119  30  7.172131  15   1
# IT          70.671642  120  30  8.141791  15   1
# Sales       73.132231  120  30  7.206612  15   1

# %% [markdown]
# #### Bonus Question:  for each department, compute the difference between the maximum and the minimum salary.
# **Hint**: try using `agg` or `apply` combined with `lambda` functions.

# %%
# your code here
employees.groupby('Department')['Salary'].agg( [lambda x: x.max() - x.min()])
# Out:
#             <lambda>
# Department
# Admin             90
# HR                89
# IT                90
# Sales             90

# %% [markdown]
# # Challenge 3
# #### Open the `Orders` dataset. Name your dataset `orders`.

# %%
# your code here
orders = pd.read_excel(r'C:\Users\radek\IronHack\IronRadek\Week5\Day3\Lab_10_Subsetting_and_Descriptive_Statistics\Orders.xlsx')

# %% [markdown]
# #### Explore your dataset by looking at the data types and summary statistics. Comment your results.

# %%
# your code here
orders.describe()
# Out:
#           Unnamed: 0      InvoiceNo           year          month  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean   278465.221859  560617.126645    2010.934259       7.612537
# std    152771.368303   13106.167695       0.247829       3.416527
# min         0.000000  536365.000000    2010.000000       1.000000
# 25%    148333.750000  549234.000000    2011.000000       5.000000
# 50%    284907.500000  561893.000000    2011.000000       8.000000
# 75%    410079.250000  572090.000000    2011.000000      11.000000
# max    541908.000000  581587.000000    2011.000000      12.000000
#
#                  day           hour       Quantity      UnitPrice  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean        3.614555      12.728247      13.021823       3.116174
# std         1.928274       2.273535     180.420210      22.096788
# min         1.000000       6.000000       1.000000       0.000000
# ...

# %%
orders.dtypes
# Out:
# Unnamed: 0             float64
# InvoiceNo              float64
# StockCode               object
# year                   float64
# month                  float64
# day                    float64
# hour                   float64
# Description             object
# Quantity               float64
# InvoiceDate     datetime64[ns]
# UnitPrice              float64
# CustomerID             float64
# Country                 object
# amount_spent           float64
# dtype: object

# %%
orders.shape
# Out:
# (397924, 14)

# %%
"""
Orders is a big dataset with almost 400 000 rows and 14 columns.
The data is mainly numeric as data are mostly of type float, but there are two columns which are categorical i.e. StockCode and Country, and there is a column with date. 
The first column can be probably droped as there is no information (no column name of what it can be). Dataset presents invoice information (number, order, sales,). It was collected in years 2010 and 2011. 
There might be an outlier in terms of quantity. BIg diffrence betwwen 4th and 3rd quantile, or there was one very big order.
"""

# %%
orders.head()
# Out:
#    Unnamed: 0  InvoiceNo StockCode    year  month  day  hour  \
# 0         0.0   536365.0    85123A  2010.0   12.0  3.0   8.0
# 1         1.0   536365.0   71053.0  2010.0   12.0  3.0   8.0
# 2         2.0   536365.0    84406B  2010.0   12.0  3.0   8.0
# 3         3.0   536365.0    84029G  2010.0   12.0  3.0   8.0
# 4         4.0   536365.0    84029E  2010.0   12.0  3.0   8.0
#
#                            Description  Quantity         InvoiceDate  \
# 0   white hanging heart t-light holder       6.0 2010-12-01 08:26:00
# 1                  white metal lantern       6.0 2010-12-01 08:26:00
# 2       cream cupid hearts coat hanger       8.0 2010-12-01 08:26:00
# 3  knitted union flag hot water bottle       6.0 2010-12-01 08:26:00
# 4       red woolly hottie white heart.       6.0 2010-12-01 08:26:00
#
#    UnitPrice  CustomerID         Country  amount_spent
# 0       2.55     17850.0  United Kingdom         15.30
# 1       3.39     17850.0  United Kingdom         20.34
# ...

# %% [markdown]
# ####  What is the average purchase price?

# %%
# your code here
#the average unit price is given here:
orders.UnitPrice.mean()
# Out:
# 3.116174480549152

# %% [markdown]
# #### What are the highest and lowest purchase prices?

# %%
# your code here
orders.UnitPrice.max()
# Out:
# 8142.75

# %%
orders.UnitPrice.min()
# Out:
# 0.0

# %%
#the same information can be read from the describe() function

# %% [markdown]
# #### Select all the customers from Spain.
# **Hint**: Remember that you are not asked to find orders from Spain but customers. A customer might have more than one order associated.

# %%
# your code here
#I selected them and grouped them by the mean value
orders[orders.Country=='Spain'].groupby('CustomerID').agg('mean')
# Out:
#                Unnamed: 0      InvoiceNo         year      month       day  \
# CustomerID
# 12354.0     166295.500000  550911.000000  2011.000000   4.000000  4.000000
# 12417.0     171232.000000  551398.000000  2011.000000   4.000000  4.000000
# 12421.0     262510.622222  559281.933333  2011.000000   6.266667  3.955556
# 12442.0     531425.500000  580955.000000  2011.000000  12.000000  2.000000
# 12445.0     478970.500000  577125.000000  2011.000000  11.000000  4.000000
# 12448.0     420313.500000  572886.000000  2011.000000  10.000000  3.000000
# 12450.0     237307.750000  557764.250000  2011.000000   6.250000  6.000000
# 12454.0     398633.000000  571255.000000  2011.000000  10.000000  5.000000
# 12455.0     289392.520833  562199.083333  2011.000000   7.625000  3.250000
# 12462.0     227907.209677  555628.580645  2011.000000   5.193548  2.290323
# 12484.0     247955.401734  558315.846821  2011.000000   6.219653  5.511561
# ...

# %%
spain = orders[orders.Country=='Spain'].groupby('CustomerID').agg(['count'])

# %% [markdown]
# #### How many customers do we have in Spain?

# %%
# your code here
#There are 30 customers from Spain
spain.shape
# Out:
# (30, 13)

# %% [markdown]
# #### Select all the customers who have bought more than 50 items.
# **Hint**: Remember that you are not asked to find orders with more than 50 items but customers who bought more than 50 items. A customer with two orders of 30 items each should appear in the selection.

# %%
# your code here
customers = orders.groupby('CustomerID')['Quantity'].agg(['sum'])
customers.head()
customers[customers['sum'] > 50]
# Out:
#                 sum
# CustomerID
# 12346.0     74215.0
# 12347.0      2458.0
# 12348.0      2341.0
# 12349.0       631.0
# 12350.0       197.0
# ...             ...
# 18278.0        66.0
# 18281.0        54.0
# 18282.0       103.0
# 18283.0      1397.0
# 18287.0      1586.0
#
# [4091 rows x 1 columns]

# %% [markdown]
# #### Select orders from Spain that include more than 50 items.

# %%
# your code here
orders[orders.Country=='Spain'][orders.Quantity > 50]
# Out:
# C:\Users\radek\AppData\Local\Temp/ipykernel_9832/364029149.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   orders[orders.Country=='Spain'][orders.Quantity > 50]
#         Unnamed: 0  InvoiceNo StockCode    year  month  day  hour  \
# 4250        6421.0   536944.0   22383.0  2010.0   12.0  5.0  12.0
# 4251        6422.0   536944.0   22384.0  2010.0   12.0  5.0  12.0
# 4252        6423.0   536944.0   20727.0  2010.0   12.0  5.0  12.0
# 4253        6424.0   536944.0   20725.0  2010.0   12.0  5.0  12.0
# 4254        6425.0   536944.0   20728.0  2010.0   12.0  5.0  12.0
# 32454      52416.0   540785.0    84997B  2011.0    1.0  2.0  11.0
# 32455      52417.0   540785.0    84997D  2011.0    1.0  2.0  11.0
# 32456      52418.0   540785.0    84997C  2011.0    1.0  2.0  11.0
# 32457      52419.0   540785.0    84997A  2011.0    1.0  2.0  11.0
# 91155     136767.0   547972.0   22383.0  2011.0    3.0  1.0  16.0
# ...

# %% [markdown]
# #### Select all free orders.

# %%
# your code here
#I understand that these are the orders for which the unit price was equal to 0.
orders[orders.UnitPrice == 0]
# Out:
#         Unnamed: 0  InvoiceNo StockCode    year  month  day  hour  \
# 6914        9302.0   537197.0   22841.0  2010.0   12.0  7.0  14.0
# 22539      33576.0   539263.0   22580.0  2010.0   12.0  4.0  14.0
# 25379      40089.0   539722.0   22423.0  2010.0   12.0  2.0  13.0
# 29080      47068.0   540372.0   22090.0  2011.0    1.0  4.0  16.0
# 29082      47070.0   540372.0   22553.0  2011.0    1.0  4.0  16.0
# 34494      56674.0   541109.0   22168.0  2011.0    1.0  4.0  15.0
# 53788      86789.0   543599.0    84535B  2011.0    2.0  4.0  13.0
# 85671     130188.0   547417.0   22062.0  2011.0    3.0  3.0  10.0
# 92875     139453.0   548318.0   22055.0  2011.0    3.0  3.0  12.0
# 97430     145208.0   548871.0   22162.0  2011.0    4.0  1.0  14.0
# 107192    157042.0   550188.0   22636.0  2011.0    4.0  4.0  18.0
# 128641    187613.0   553000.0   47566.0  2011.0    5.0  4.0  15.0
# 137127    198383.0   554037.0   22619.0  2011.0    5.0  5.0  14.0
# ...

# %% [markdown]
# #### Select all orders whose description starts with `lunch bag`.
# **Hint**: use string functions.

# %%
# your code here

orders[orders.Description.str.startswith('lunch bag')]
# Out:
#         Unnamed: 0  InvoiceNo StockCode    year  month  day  hour  \
# 93            93.0   536378.0   20725.0  2010.0   12.0  3.0   9.0
# 172          174.0   536385.0   22662.0  2010.0   12.0  3.0   9.0
# 354          363.0   536401.0   22662.0  2010.0   12.0  3.0  11.0
# 359          368.0   536401.0   20725.0  2010.0   12.0  3.0  11.0
# 360          369.0   536401.0   22382.0  2010.0   12.0  3.0  11.0
# ...            ...        ...       ...     ...    ...  ...   ...
# 397465    540436.0   581486.0   23207.0  2011.0   12.0  5.0   9.0
# 397713    541695.0   581538.0   20727.0  2011.0   12.0  5.0  11.0
# 397714    541696.0   581538.0   20725.0  2011.0   12.0  5.0  11.0
# 397877    541862.0   581581.0   23681.0  2011.0   12.0  5.0  12.0
# 397880    541865.0   581583.0   20725.0  2011.0   12.0  5.0  12.0
#
#                         Description  Quantity         InvoiceDate  UnitPrice  \
# 93          lunch bag red retrospot      10.0 2010-12-01 09:37:00       1.65
# ...

# %% [markdown]
# #### Select all `lunch bag` orders made in 2011.

# %%
# your code here
orders[(orders.Description.str.contains('lunch bag'))& (orders.year == 2011)]
# Out:
#         Unnamed: 0  InvoiceNo StockCode    year  month  day  hour  \
# 26340      42678.0   540015.0   20725.0  2011.0    1.0  2.0  11.0
# 26341      42679.0   540015.0   20726.0  2011.0    1.0  2.0  11.0
# 26512      42851.0   540023.0   22382.0  2011.0    1.0  2.0  12.0
# 26513      42852.0   540023.0   20726.0  2011.0    1.0  2.0  12.0
# 26860      43616.0   540098.0   22384.0  2011.0    1.0  2.0  15.0
# ...            ...        ...       ...     ...    ...  ...   ...
# 397465    540436.0   581486.0   23207.0  2011.0   12.0  5.0   9.0
# 397713    541695.0   581538.0   20727.0  2011.0   12.0  5.0  11.0
# 397714    541696.0   581538.0   20725.0  2011.0   12.0  5.0  11.0
# 397877    541862.0   581581.0   23681.0  2011.0   12.0  5.0  12.0
# 397880    541865.0   581583.0   20725.0  2011.0   12.0  5.0  12.0
#
#                         Description  Quantity         InvoiceDate  UnitPrice  \
# 26340       lunch bag red retrospot      10.0 2011-01-04 11:40:00       1.65
# ...

# %% [markdown]
# #### Show the frequency distribution of the amount spent in Spain.

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
# your code here
spain_orders = orders[(orders.Country =='Spain')]
sns.distplot(spain_orders['amount_spent'])
# Out:
# C:\Users\radek\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='amount_spent', ylabel='Density'>

# %%
spain_orders.hist(column='amount_spent', bins=10)
# Out:
# array([[<AxesSubplot:title={'center':'amount_spent'}>]], dtype=object)

# %% [markdown]
# #### Select all orders made in the month of August.

# %%
# your code here
#August is 8th month
orders[orders.month == 8]
# Out:
#         Unnamed: 0  InvoiceNo StockCode    year  month  day  hour  \
# 199475    285421.0   561904.0   22075.0  2011.0    8.0  1.0   8.0
# 199476    285422.0   561904.0    85049E  2011.0    8.0  1.0   8.0
# 199477    285423.0   561905.0   21385.0  2011.0    8.0  1.0   9.0
# 199478    285424.0   561905.0    84970L  2011.0    8.0  1.0   9.0
# 199479    285425.0   561905.0    84970S  2011.0    8.0  1.0   9.0
# ...            ...        ...       ...     ...    ...  ...   ...
# 226483    320688.0   565067.0   22644.0  2011.0    8.0  3.0  17.0
# 226484    320689.0   565067.0   22645.0  2011.0    8.0  3.0  17.0
# 226485    320690.0   565067.0   22637.0  2011.0    8.0  3.0  17.0
# 226486    320691.0   565067.0   22646.0  2011.0    8.0  3.0  17.0
# 226487    320692.0   565067.0   22741.0  2011.0    8.0  3.0  17.0
#
#                                 Description  Quantity         InvoiceDate  \
# 199475          6 ribbons elegant christmas      96.0 2011-08-01 08:30:00
# ...

# %% [markdown]
# #### Find the number of orders made by each country in the month of August.
# **Hint**: Use value_counts().

# %%
# your code here
august = orders[orders.month == 8]
august.groupby('Country')['Country'].agg(['count'])
# Out:
#                  count
# Country
# Australia          107
# Austria             88
# Belgium            194
# Canada               5
# Channel Islands    140
# Denmark             16
# EIRE               593
# Finland             61
# France             569
# Germany            795
# Iceland             22
# Israel             171
# Italy               95
# Malta               55
# Netherlands        280
# Norway              77
# Poland              17
# Portugal            41
# Spain              252
# Sweden              40
# Switzerland        267
# United Kingdom   23105
# Unspecified         23

# %%
august['Country'].value_counts()
# Out:
# United Kingdom     23105
# Germany              795
# EIRE                 593
# France               569
# Netherlands          280
# Switzerland          267
# Spain                252
# Belgium              194
# Israel               171
# Channel Islands      140
# Australia            107
# Italy                 95
# Austria               88
# Norway                77
# Finland               61
# Malta                 55
# Portugal              41
# Sweden                40
# Unspecified           23
# Iceland               22
# Poland                17
# Denmark               16
# Canada                 5
# Name: Country, dtype: int64

# %% [markdown]
# #### What's the  average amount of money spent by country?

# %%
# your code here
orders.groupby('Country')['amount_spent'].agg(['mean'])
# Out:
#                             mean
# Country
# Australia             116.895620
# Austria                25.624824
# Bahrain                32.258824
# Belgium                20.283772
# Brazil                 35.737500
# Canada                 24.280662
# Channel Islands        27.340160
# Cyprus                 22.134169
# Czech Republic         33.069600
# Denmark                49.882474
# EIRE                   36.687745
# European Community     21.670833
# Finland                32.913985
# France                 25.056827
# Germany                25.311562
# Greece                 32.831172
# Iceland                23.681319
# Israel                 29.119718
# Italy                  23.064960
# Japan                 116.561900
# Lebanon                37.641778
# Lithuania              47.458857
# Malta                  24.335625
# Netherlands           120.798282
# Norway                 33.736418
# Poland                 22.226212
# Portugal               22.872702
# ...

# %% [markdown]
# #### What's the most expensive item?

# %%
# your code here
orders[orders.UnitPrice == orders.UnitPrice.max()]
# Out:
#         Unnamed: 0  InvoiceNo StockCode    year  month  day  hour Description  \
# 118352    173382.0   551697.0      POST  2011.0    5.0  2.0  13.0     postage
#
#         Quantity         InvoiceDate  UnitPrice  CustomerID         Country  \
# 118352       1.0 2011-05-03 13:46:00    8142.75     16029.0  United Kingdom
#
#         amount_spent
# 118352       8142.75

# %% [markdown]
# #### What is the average amount spent per year?

# %%
# your code here
orders.groupby('year')['amount_spent'].agg(['mean'])
# Out:
#              mean
# year
# 2010.0  21.892733
# 2011.0  22.430074
