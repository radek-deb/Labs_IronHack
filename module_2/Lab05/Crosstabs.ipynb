# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import random

# %% [markdown]
# ### 1. Import the moovies dataset

# %% [markdown]
# # https://www.kaggle.com/carolzhangdc/imdb-5000-movie-dataset

# %%
movie = pd.read_csv(r'C:\Users\radek\IronHack\IronRadek\Week4\Day3\Lab05\movie_metadata.csv')

# %%
movie.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %% [markdown]
# ### 2. Use crosstabs to show the number of moovies per country

# %%
#As a second parameter I chose color and I used margins to have a Total number in the final column
count_movie =pd.crosstab(movie.country, movie.color, margins=True, margins_name="Total")
count_movie
# Out:
# color                  Black and White  Color  Total
# country
# Afghanistan                          0      1      1
# Argentina                            0      4      4
# Aruba                                0      1      1
# Australia                            1     54     55
# Bahamas                              0      1      1
# ...                                ...    ...    ...
# UK                                  20    427    447
# USA                                149   3644   3793
# United Arab Emirates                 0      1      1
# West Germany                         0      3      3
# Total                              209   4812   5021
#
# [66 rows x 3 columns]

# %%
#In order to just have movies by country I can read it like that
count_movie['Total']
# Out:
# country
# Afghanistan                1
# Argentina                  4
# Aruba                      1
# Australia                 55
# Bahamas                    1
#                         ...
# UK                       447
# USA                     3793
# United Arab Emirates       1
# West Germany               3
# Total                   5021
# Name: Total, Length: 66, dtype: int64

# %% [markdown]
# ### 3. Create a crosstab to show the number of films per director and genre splitted by country

# %%
pd.crosstab(movie.country, [movie.director_name, movie.genres],  margins=True, margins_name="Total")
# Out:
# director_name                                 A. Raven Cruz  \
# genres               Action|Adventure|Comedy|Fantasy|Sci-Fi
# country
# Afghanistan                                               0
# Argentina                                                 0
# Aruba                                                     0
# Australia                                                 0
# Bahamas                                                   0
# ...                                                     ...
# UK                                                        0
# USA                                                       1
# United Arab Emirates                                      0
# West Germany                                              0
# Total                                                     1
#
# director_name                                  Aaron Hann Aaron Schneider  \
# genres               Drama|Horror|Mystery|Sci-Fi|Thriller   Drama|Mystery
# country
# ...

# %%
#The Table above is not very clear that is why I will crosstab it abain but only with directors
pd.crosstab(movie.country, movie.director_name,  margins=True, margins_name="Total")
# Out:
# director_name         A. Raven Cruz  Aaron Hann  Aaron Schneider  \
# country
# Afghanistan                       0           0                0
# Argentina                         0           0                0
# Aruba                             0           0                0
# Australia                         0           0                0
# Bahamas                           0           0                0
# ...                             ...         ...              ...
# UK                                0           0                0
# USA                               1           1                1
# United Arab Emirates              0           0                0
# West Germany                      0           0                0
# Total                             1           1                1
#
# director_name         Aaron Seltzer  Abel Ferrara  Adam Brooks  Adam Carolla  \
# country
# Afghanistan                       0             0            0             0
# ...

# %%
#Another proposition 
pd.crosstab([movie['director_name'], movie['genres']], movie['country'])
# Out:
# country                                                    Afghanistan  \
# director_name      genres
# A. Raven Cruz      Action|Adventure|Comedy|Fantasy|Sci-Fi            0
# Aaron Hann         Drama|Horror|Mystery|Sci-Fi|Thriller              0
# Aaron Schneider    Drama|Mystery                                     0
# Aaron Seltzer      Comedy|Romance                                    0
# Abel Ferrara       Crime|Drama                                       0
# ...                                                                ...
# Zoran Lisinac      Comedy|Music|Romance                              0
# Álex de la Iglesia Crime|Mystery|Thriller                            0
# Émile Gaudreault   Comedy|Drama                                      0
# Éric Tessier       Action|Drama|Horror|Thriller                      0
# Étienne Faure      Drama|Musical|Romance                             0
#
# country                                                    Argentina  Aruba  \
# ...

# %% [markdown]
# ### 4. Average duration of filmes grouped by color

# %%
#In order to coross the color with something I used genres
pd.crosstab(movie.genres, movie.color, values=movie.duration, aggfunc='mean')
# Out:
# color                                                Black and White  \
# genres
# Action                                                         111.0
# Action|Adventure                                                 NaN
# Action|Adventure|Animation|Comedy|Crime|Family|...               NaN
# Action|Adventure|Animation|Comedy|Drama|Family|...               NaN
# Action|Adventure|Animation|Comedy|Family                         NaN
# ...                                                              ...
# Sci-Fi|Thriller                                                  NaN
# Thriller                                                         NaN
# Thriller|War                                                   133.0
# Thriller|Western                                                85.0
# Western                                                          NaN
#
# color                                                    Color
# genres
# ...

# %% [markdown]
# ### 5. Average number of likes per director (assuming that total film's likes are counted as a sum of actor's likes)

# %%
movie.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
#Firstly I create a column with the film likes

movie['film_likes']= movie['actor_1_facebook_likes'] + movie['actor_2_facebook_likes'] + movie['actor_3_facebook_likes']

# %%
movie.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
#This is a very big dataframe so I will save it as a variable and show only the last column  in the cell below
likes=pd.crosstab(movie.director_name, movie.film_likes, values=movie['film_likes'], aggfunc='sum', margins=True,  margins_name="Total" )

# %%
likes['Total']
# Out:
# director_name
# A. Raven Cruz             1094.0
# Aaron Hann                 406.0
# Aaron Schneider          16970.0
# Aaron Seltzer             4598.0
# Abel Ferrara              2198.0
#                          ...
# Álex de la Iglesia         702.0
# Émile Gaudreault           917.0
# Éric Tessier                72.0
# Étienne Faure               19.0
# Total                 44334843.0
# Name: Total, Length: 2386, dtype: float64
