# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
# Libraries
import pandas as pd
import numpy as np

# %% [markdown]
# # Challenge 1 - Index Functions
#
# In this challenge, we will practice the advanced functions introduced in the lesson. However, before we start, we will load and evaluate our dataset.
#
# Load the dataset from Ironhack's database:
# * db: `admissions predict`
# * table: `admissions predict`

# %%
# your code here
admissions = pd.read_csv(r'C:\Users\radek\IronHack\IronRadek\Week3\Day3\Lab_29_1\Admission_Predict.csv')

# %%
admissions.shape
# Out:
# (385, 9)

# %%
admissions.head(5)
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        316          104                  3  3.0   3.5  8.00
# 2           3        322          110                  3  3.5   2.5  8.67
# 3           4        314          103                  2  2.0   3.0  8.21
# 4           5        330          115                  5  4.5   3.0  9.34
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.72
# 2         1              0.80
# 3         0              0.65
# 4         1              0.90

# %% [markdown]
# Remove trailing spaces at the end of the column names if there are any.

# %%
# your code here
admissions.columns = [column.strip(' ') for column in admissions.columns]
admissions.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR', 'CGPA', 'Research', 'Chance of Admit'],
#       dtype='object')

# %% [markdown]
# Let's evaluate the dataset by looking at the `head` function.

# %%
# your code here
admissions.head(5)
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0           1        337          118                  4  4.5  4.5  9.65
# 1           2        316          104                  3  3.0  3.5  8.00
# 2           3        322          110                  3  3.5  2.5  8.67
# 3           4        314          103                  2  2.0  3.0  8.21
# 4           5        330          115                  5  4.5  3.0  9.34
#
#    Research  Chance of Admit
# 0         1             0.92
# 1         1             0.72
# 2         1             0.80
# 3         0             0.65
# 4         1             0.90

# %% [markdown]
# Before beginning to work with this dataset and evaluating graduate admissions data, we will verify that there is no missing data in the dataset. Do this in the cell below.

# %%
# your code here
#isnull function return True if a value is missing
#by running value_counts on the whole thing I confirmed that there are no data missing
admissions.isnull().value_counts()
# Out:
# Serial No.  GRE Score  TOEFL Score  University Rating  SOP    LOR    CGPA   Research  Chance of Admit
# False       False      False        False              False  False  False  False     False              385
# dtype: int64

# %%
# I can check for missing data also in diffrent way:
mv=admissions.isna().sum()
mv
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %% [markdown]
# Interestingly, there is a column that uniquely identifies the applicants. This column is the serial number column. Instead of having our own index, we should make this column our index. Do this in the cell below. Keep the column in the dataframe in addition to making it an index.

# %%
# your code here
# I will use set_index function

admissions = admissions.set_index(admissions['Serial No.'])
admissions
# Out:
#             Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  \
# Serial No.
# 1                    1        337          118                  4  4.5  4.5
# 2                    2        316          104                  3  3.0  3.5
# 3                    3        322          110                  3  3.5  2.5
# 4                    4        314          103                  2  2.0  3.0
# 5                    5        330          115                  5  4.5  3.0
# ...                ...        ...          ...                ...  ...  ...
# 381                381        324          110                  3  3.5  3.5
# 382                382        325          107                  3  3.0  3.5
# 383                383        330          116                  4  5.0  4.5
# 384                384        312          103                  3  3.5  4.0
# 385                385        333          117                  4  5.0  4.0
#
#             CGPA  Research  Chance of Admit
# ...

# %%
# I can drop no serial No. column since it was dupicated
admissions.drop(columns = 'Serial No.')
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# Serial No.
# 1                 337          118                  4  4.5  4.5  9.65
# 2                 316          104                  3  3.0  3.5  8.00
# 3                 322          110                  3  3.5  2.5  8.67
# 4                 314          103                  2  2.0  3.0  8.21
# 5                 330          115                  5  4.5  3.0  9.34
# ...               ...          ...                ...  ...  ...   ...
# 381               324          110                  3  3.5  3.5  9.04
# 382               325          107                  3  3.0  3.5  9.11
# 383               330          116                  4  5.0  4.5  9.45
# 384               312          103                  3  3.5  4.0  8.78
# 385               333          117                  4  5.0  4.0  9.66
#
#             Research  Chance of Admit
# Serial No.
# 1                  1             0.92
# ...

# %% [markdown]
# Turns out that `GRE Score` and `CGPA` also uniquely identify the data. Show this in the cell below.

# %%
# your code here
# admissions have 385 unique rows the two cells below show that GRE Score alone and CGPA alone is not unique, but maybe they combination will be
len(list(admissions['GRE Score'].unique()))
# Out:
# 49

# %%
len(list(admissions['CGPA'].unique()))
# Out:
# 168

# %%
#Combination of GRE Score ans CGPA
admissions['GRE-CGPA']= admissions['GRE Score'].apply(str) + '-' + admissions['CGPA'].apply(str)
admissions.head(5)
# Out:
#             Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  \
# Serial No.
# 1                    1        337          118                  4  4.5  4.5
# 2                    2        316          104                  3  3.0  3.5
# 3                    3        322          110                  3  3.5  2.5
# 4                    4        314          103                  2  2.0  3.0
# 5                    5        330          115                  5  4.5  3.0
#
#             CGPA  Research  Chance of Admit  GRE-CGPA
# Serial No.
# 1           9.65         1             0.92  337-9.65
# 2           8.00         1             0.72   316-8.0
# 3           8.67         1             0.80  322-8.67
# 4           8.21         0             0.65  314-8.21
# 5           9.34         1             0.90  330-9.34

# %%
#Now they create a unique values which can identify admissions
len(list(admissions['GRE-CGPA'].unique()))
# Out:
# 385

# %%
admissions['GRE-CGPA'].value_counts()
# Out:
# 337-9.65    1
# 334-9.87    1
# 329-9.45    1
# 322-8.96    1
# 315-7.95    1
#            ..
# 303-8.65    1
# 339-9.76    1
# 333-9.35    1
# 326-9.1     1
# 333-9.66    1
# Name: GRE-CGPA, Length: 385, dtype: int64

# %%
#Now the combination of both GRE Score and CGPA gives unique identification of the data as len of list made out of unique items in that column is equal to the number of rows in the dataframe

# %% [markdown]
# Replace the index with an index comprised of two columns - `GRE Score` and `CGPA`. Remove the columns from the dataset as well. Make sure to use `inplace=True`.

# %% [markdown]
# Now change the index back to a sequence starting at zero using the `reset_index` function. Make sure to use `inplace=True`.

# %%
# your code here
admissions.set_index('GRE-CGPA', inplace=True)

# %%
admissions.head(5)
# Out:
#           Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  \
# GRE-CGPA
# 337-9.65           1        337          118                  4  4.5  4.5
# 316-8.0            2        316          104                  3  3.0  3.5
# 322-8.67           3        322          110                  3  3.5  2.5
# 314-8.21           4        314          103                  2  2.0  3.0
# 330-9.34           5        330          115                  5  4.5  3.0
#
#           CGPA  Research  Chance of Admit
# GRE-CGPA
# 337-9.65  9.65         1             0.92
# 316-8.0   8.00         1             0.72
# 322-8.67  8.67         1             0.80
# 314-8.21  8.21         0             0.65
# 330-9.34  9.34         1             0.90

# %%
cols_to_drop = ['GRE Score', 'CGPA']
admissions.drop(cols_to_drop, axis=1, inplace=True)
admissions.head(5)
# Out:
#           Serial No.  TOEFL Score  University Rating  SOP  LOR   Research  \
# GRE-CGPA
# 337-9.65           1          118                  4  4.5   4.5         1
# 316-8.0            2          104                  3  3.0   3.5         1
# 322-8.67           3          110                  3  3.5   2.5         1
# 314-8.21           4          103                  2  2.0   3.0         0
# 330-9.34           5          115                  5  4.5   3.0         1
#
#           Chance of Admit
# GRE-CGPA
# 337-9.65              0.92
# 316-8.0               0.72
# 322-8.67              0.80
# 314-8.21              0.65
# 330-9.34              0.90

# %%
admissions.reset_index(inplace=True)

# %%
admissions.head(4)
# Out:
#    GRE-CGPA  Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  \
# 0  337-9.65           1        337          118                  4  4.5  4.5
# 1   316-8.0           2        316          104                  3  3.0  3.5
# 2  322-8.67           3        322          110                  3  3.5  2.5
# 3  314-8.21           4        314          103                  2  2.0  3.0
#
#    CGPA  Research  Chance of Admit
# 0  9.65         1             0.92
# 1  8.00         1             0.72
# 2  8.67         1             0.80
# 3  8.21         0             0.65

# %% [markdown]
# # Challenge 2 - Advanced Functions
#
# In this part of the lab, we would like to test complex conditions on the entire dataset at once. Let's start by finding the number of rows where the CGPA is higher than 9 and the student has conducted research.

# %%
# your code here
filtered = admissions[(admissions['CGPA'] > 9) & (admissions['Research']==1)]
filtered.head(5)
# Out:
#     GRE-CGPA  Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  \
# 0   337-9.65           1        337          118                  4  4.5  4.5
# 4   330-9.34           5        330          115                  5  4.5  3.0
# 10   328-9.1          11        328          112                  4  4.0  4.5
# 19   328-9.5          20        328          116                  5  5.0  5.0
# 20   334-9.7          21        334          119                  5  5.0  4.5
#
#     CGPA  Research  Chance of Admit
# 0   9.65         1             0.92
# 4   9.34         1             0.90
# 10  9.10         1             0.78
# 19  9.50         1             0.94
# 20  9.70         1             0.95

# %%
filtered.shape
# Out:
# (101, 10)

# %% [markdown]
# Now return all the rows where the CGPA is greater than 9 and the SOP score is less than 3.5. Find the mean chance of admit for these applicants.

# %%
# your code here
filtered2 = admissions[(admissions['CGPA'] > 9) & (admissions['SOP']<3.5)]
filtered2
# Out:
#      GRE-CGPA  Serial No.  GRE Score  TOEFL Score  University Rating  SOP  \
# 28    338-9.4          29        338          118                  4  3.0
# 62   327-9.02          63        327          114                  3  3.0
# 140  326-9.11         141        326          114                  3  3.0
# 217  324-9.01         218        324          111                  4  3.0
# 381  325-9.11         382        325          107                  3  3.0
#
#      LOR  CGPA  Research  Chance of Admit
# 28   4.5  9.40         1             0.91
# 62   3.0  9.02         0             0.61
# 140  3.0  9.11         1             0.83
# 217  3.0  9.01         1             0.82
# 381  3.5  9.11         1             0.84

# %%
#The mean chance of admit is presented here:
filtered2.mean()
# Out:
# C:\Users\radek\AppData\Local\Temp/ipykernel_14428/115499162.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   filtered2.mean()
# Serial No.           166.600
# GRE Score            328.000
# TOEFL Score          112.800
# University Rating      3.400
# SOP                    3.000
# LOR                    3.400
# CGPA                   9.130
# Research               0.800
# Chance of Admit        0.802
# dtype: float64

# %%
filtered2.shape
# Out:
# (5, 10)

# %% [markdown]
# We would like to create a deciding factor column for each student. We standardize several columns and then pick the most important factor from a lookup table. If the standardized value is above 0.8, the student will be accepted.
#
# We will start by creating a standardized column for `CGPA`, `GRE Score` and `LOR`. We will name these columns `CGPA_std`, `GRE_std`, and `LOR_std` respecively.
#
# Recall that standardizing a column is done by subtracting the mean of the column from all observations in the column and then dividing each observation in the column by the column's standard deviation.
#
# In the cell below, write a standardization function (a function that takes a column as input and returns a standardized column as output). Make sure to use the `numpy` versions of mean and standard deviation.

# %%
def standardize(col):
    """
    This function takes a column from a dataframe 
    and returns a standardized column by subtracting the column's mean
    and dividing by the column's standard deviation.
    """
    
    # your code here
    st_col = (col - col.mean())/col.std()
    return st_col

# %% [markdown]
# Now create the standardized columns `CGPA_std`, `GRE_std`, and `LOR_std` and add them to the `admissions` dataframe.

# %%
# your code here
admissions['CGPA_std']= standardize(admissions['CGPA'])
admissions.head(5)
# Out:
#    GRE-CGPA  Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  \
# 0  337-9.65           1        337          118                  4  4.5  4.5
# 1   316-8.0           2        316          104                  3  3.0  3.5
# 2  322-8.67           3        322          110                  3  3.5  2.5
# 3  314-8.21           4        314          103                  2  2.0  3.0
# 4  330-9.34           5        330          115                  5  4.5  3.0
#
#    CGPA  Research  Chance of Admit  CGPA_std
# 0  9.65         1             0.92  1.747900
# 1  8.00         1             0.72 -0.991211
# 2  8.67         1             0.80  0.121034
# 3  8.21         0             0.65 -0.642597
# 4  9.34         1             0.90  1.233279

# %%
admissions['GRE_std']= standardize(admissions['GRE Score'])
admissions['LOR_std']= standardize(admissions['LOR'])

# %%
admissions.head(5)
# Out:
#    GRE-CGPA  Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  \
# 0  337-9.65           1        337          118                  4  4.5  4.5
# 1   316-8.0           2        316          104                  3  3.0  3.5
# 2  322-8.67           3        322          110                  3  3.5  2.5
# 3  314-8.21           4        314          103                  2  2.0  3.0
# 4  330-9.34           5        330          115                  5  4.5  3.0
#
#    CGPA  Research  Chance of Admit  CGPA_std   GRE_std   LOR_std
# 0  9.65         1             0.92  1.747900  1.753381  1.191647
# 1  8.00         1             0.72 -0.991211 -0.063367  0.076740
# 2  8.67         1             0.80  0.121034  0.455704 -1.038166
# 3  8.21         0             0.65 -0.642597 -0.236391 -0.480713
# 4  9.34         1             0.90  1.233279  1.147798 -0.480713

# %% [markdown]
# We will generate the decision choice at random using the code below. Please run the cell.

# %%
# Libraries
from random import choices

# %%
std_columns = ['CGPA_std', 'GRE_std', 'LOR_std']

admissions['decision_choice'] = choices(std_columns, k=admissions.shape[0])

# %%
#df['value'] = df.lookup(df.index, df['best'])
admissions['decision_value']= admissions.lookup(admissions.index, admissions['decision_choice'])
# Out:
# C:\Users\radek\AppData\Local\Temp/ipykernel_14428/51944118.py:2: FutureWarning: The 'lookup' method is deprecated and will beremoved in a future version.You can use DataFrame.melt and DataFrame.locas a substitute.
#   admissions['decision_value']= admissions.lookup(admissions.index, admissions['decision_choice'])

# %% [markdown]
# Now create the deciding column using the `lookup` function. The lookup column is `decision_choice` found above. Call the column resulting from the lookup function `deciding_column` and add it to the `admissions` dataframe.

# %%
# your code here
admissions.lookup(admissions.index,admissions['decision_choice']  )
# Out:
# C:\Users\radek\AppData\Local\Temp/ipykernel_14428/148937727.py:2: FutureWarning: The 'lookup' method is deprecated and will beremoved in a future version.You can use DataFrame.melt and DataFrame.locas a substitute.
#   admissions.lookup(admissions.index,admissions['decision_choice']  )
# array([ 1.74789964,  0.07674031, -1.03816607, -0.23639072, -0.48071288,
#        -0.65919752,  0.6341935 , -1.2745325 , -0.48071288,  0.66885609,
#         1.19164669, -0.48071288, -0.65919752, -1.03816607, -0.48071288,
#        -0.99121092,  0.33684269, -0.16117741, -1.59561926,  1.74909988,
#         1.19164669,  1.6668692 ,  0.07674031, -1.82124442, -1.59561926,
#        -0.58243798, -0.82520422,  0.6341935 ,  1.83989283,  1.66489629,
#         1.99690969,  1.74909988, -0.32718412, -1.32322432, -1.10150887,
#         0.07674031, -0.48071288, -0.0633671 , -0.16117741,  0.83486279,
#         0.80175105,  0.6341935 ,  1.74909988,  0.6341935 ,  0.36919198,
# ...

# %%
admissions.head(5)
# Out:
#    GRE-CGPA  Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  \
# 0  337-9.65           1        337          118                  4  4.5  4.5
# 1   316-8.0           2        316          104                  3  3.0  3.5
# 2  322-8.67           3        322          110                  3  3.5  2.5
# 3  314-8.21           4        314          103                  2  2.0  3.0
# 4  330-9.34           5        330          115                  5  4.5  3.0
#
#    CGPA  Research  Chance of Admit  CGPA_std   GRE_std   LOR_std  \
# 0  9.65         1             0.92  1.747900  1.753381  1.191647
# 1  8.00         1             0.72 -0.991211 -0.063367  0.076740
# 2  8.67         1             0.80  0.121034  0.455704 -1.038166
# 3  8.21         0             0.65 -0.642597 -0.236391 -0.480713
# 4  9.34         1             0.90  1.233279  1.147798 -0.480713
#
#   decision_choice  decision_value
# 0        CGPA_std        1.747900
# 1         LOR_std        0.076740
# ...

# %% [markdown]
# Create a column called `decision` in the `admissions` dataframe. Assign 1 to this column if the value of `deciding_column` is greater than 0.8 and 0 otherwise.

# %%
# your code here
admissions['Admit']=np.where(admissions['decision_value'] > 0.8, 1, 0)
#animals['wt_ratio_zero_check']=np.where(animals['body'] !=0, (animals['brain']/1000)/animals['body_kg'], 0)
admissions.head(5)
# Out:
#    GRE-CGPA  Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  \
# 0  337-9.65           1        337          118                  4  4.5  4.5
# 1   316-8.0           2        316          104                  3  3.0  3.5
# 2  322-8.67           3        322          110                  3  3.5  2.5
# 3  314-8.21           4        314          103                  2  2.0  3.0
# 4  330-9.34           5        330          115                  5  4.5  3.0
#
#    CGPA  Research  Chance of Admit  CGPA_std   GRE_std   LOR_std  \
# 0  9.65         1             0.92  1.747900  1.753381  1.191647
# 1  8.00         1             0.72 -0.991211 -0.063367  0.076740
# 2  8.67         1             0.80  0.121034  0.455704 -1.038166
# 3  8.21         0             0.65 -0.642597 -0.236391 -0.480713
# 4  9.34         1             0.90  1.233279  1.147798 -0.480713
#
#   decision_choice  decision_value  Admit
# 0        CGPA_std        1.747900      1
# ...

# %%
admissions['Admit'].value_counts()
# Out:
# 0    298
# 1     87
# Name: Admit, dtype: int64

# %%
#87 Students was admited

# %% [markdown]
# How many applicants will be accepted to the program using the decision column? Compute the result below.

# %%
# your code here
#I answered this question above. 87 Students will be admitted

# %% [markdown]
# # Challenge 3 - Method Chaining
#
# To increase our coding efficiency, let's make a number of changes to our dataframe in one line of code.
#
# In the cell below, remove all non character symbols from the column names, replace all spaces in column names to underscores, and change all upper case characters to lower case. Assign these new column values to `admissions.columns`.

# %%
# your code here
cols = list(admissions.columns)
cols
# Out:
# ['GRE-CGPA',
#  'Serial No.',
#  'GRE Score',
#  'TOEFL Score',
#  'University Rating',
#  'SOP',
#  'LOR',
#  'CGPA',
#  'Research',
#  'Chance of Admit',
#  'CGPA_std',
#  'GRE_std',
#  'LOR_std',
#  'decision_choice',
#  'decision_value',
#  'Admit']

# %%
admissions.columns = [col.replace(' ','_').lower().replace('[#,@,&,.]', '') for col in cols]
admissions.columns
# Out:
# Index(['gre-cgpa', 'serial_no.', 'gre_score', 'toefl_score',
#        'university_rating', 'sop', 'lor', 'cgpa', 'research',
#        'chance_of_admit', 'cgpa_std', 'gre_std', 'lor_std', 'decision_choice',
#        'decision_value', 'admit'],
#       dtype='object')

# %% [markdown]
# In the cell below, give all student with a university rating of 4 or higher a 10 point boost on their GRE score and split the column into 4 bins using the `cut` function. Assign this new score to the variable `adjusted_gre`.

# %%
# your code here
admissions.head(5)
# Out:
#    gre-cgpa  serial_no.  gre_score  toefl_score  university_rating  sop  lor  \
# 0  337-9.65           1        337          118                  4  4.5  4.5
# 1   316-8.0           2        316          104                  3  3.0  3.5
# 2  322-8.67           3        322          110                  3  3.5  2.5
# 3  314-8.21           4        314          103                  2  2.0  3.0
# 4  330-9.34           5        330          115                  5  4.5  3.0
#
#    cgpa  research  chance_of_admit  cgpa_std   gre_std   lor_std  \
# 0  9.65         1             0.92  1.747900  1.753381  1.191647
# 1  8.00         1             0.72 -0.991211 -0.063367  0.076740
# 2  8.67         1             0.80  0.121034  0.455704 -1.038166
# 3  8.21         0             0.65 -0.642597 -0.236391 -0.480713
# 4  9.34         1             0.90  1.233279  1.147798 -0.480713
#
#   decision_choice  decision_value  admit
# 0        CGPA_std        1.747900      1
# ...

# %%
#I create a new column with the boosted gre score
admissions['adjusted_gre']=np.where(admissions['university_rating'] > 4, admissions['gre_score']+10, admissions['gre_score'])

# %%
#Now I check the head again to see if everything worked correctly 
admissions.head(5)
# Out:
#    gre-cgpa  serial_no.  gre_score  toefl_score  university_rating  sop  lor  \
# 0  337-9.65           1        337          118                  4  4.5  4.5
# 1   316-8.0           2        316          104                  3  3.0  3.5
# 2  322-8.67           3        322          110                  3  3.5  2.5
# 3  314-8.21           4        314          103                  2  2.0  3.0
# 4  330-9.34           5        330          115                  5  4.5  3.0
#
#    cgpa  research  chance_of_admit  cgpa_std   gre_std   lor_std  \
# 0  9.65         1             0.92  1.747900  1.753381  1.191647
# 1  8.00         1             0.72 -0.991211 -0.063367  0.076740
# 2  8.67         1             0.80  0.121034  0.455704 -1.038166
# 3  8.21         0             0.65 -0.642597 -0.236391 -0.480713
# 4  9.34         1             0.90  1.233279  1.147798 -0.480713
#
#   decision_choice  decision_value  admit  adjusted_gre
# 0        CGPA_std        1.747900      1           337
# ...

# %%
#I made 4 labels to divide the new column into 4 bins
gre_labels = ['bad', 'medium', 'good','very good']
adjusted_gre_bins = pd.cut(admissions['adjusted_gre'],4, labels=gre_labels)

# %%
adjusted_gre_bins
# Out:
# 0      very good
# 1         medium
# 2           good
# 3         medium
# 4      very good
#          ...
# 380         good
# 381         good
# 382         good
# 383       medium
# 384         good
# Name: adjusted_gre, Length: 385, dtype: category
# Categories (4, object): ['bad' < 'medium' < 'good' < 'very good']
