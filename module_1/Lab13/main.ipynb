# %% [markdown]
# Challange to find in our data-lab repo:
# - number of forks
# - number of commits
# - languages used

# %%
import json
import requests
import pandas as pd

response = requests.get('https://api.github.com/repos/ta-data-par/DAFT_NOV_21_01/forks')
response.status_code
# Out:
# 200

# %%
result = response.json()

# %%
#The lenght of response will be equal to the number of forks
len(result)
# Out:
# 18

# %% [markdown]
# Number of commits:

# %%
response_commit = requests.get('https://api.github.com/repos/ta-data-par/DAFT_NOV_21_01/commits')
response_commit.status_code
# Out:
# 200

# %%
len(response_commit.json())
# Out:
# 30

# %%
print(response_commit.json())
# Out:
# [{'sha': '565f69394722cd0ffda494d2f0cd0716b87fa1de', 'node_id': 'C_kwDOGbJx_9oAKDU2NWY2OTM5NDcyMmNkMGZmZGE0OTRkMmYwY2QwNzE2Yjg3ZmExZGU', 'commit': {'author': {'name': 'ta-data-par', 'email': '50342645+ta-data-par@users.noreply.github.com', 'date': '2021-12-06T12:48:28Z'}, 'committer': {'name': 'GitHub', 'email': 'noreply@github.com', 'date': '2021-12-06T12:48:28Z'}, 'message': 'Update README.md', 'tree': {'sha': '445a7b1adeb0ac7b0d63336dba6b226383238b44', 'url': 'https://api.github.com/repos/ta-data-par/DAFT_NOV_21_01/git/trees/445a7b1adeb0ac7b0d63336dba6b226383238b44'}, 'url': 'https://api.github.com/repos/ta-data-par/DAFT_NOV_21_01/git/commits/565f69394722cd0ffda494d2f0cd0716b87fa1de', 'comment_count': 0, 'verification': {'verified': True, 'reason': 'valid', 'signature': '-----BEGIN PGP SIGNATURE-----\n\nwsBcBAABCAAQBQJhrgacCRBK7hj4Ov3rIwAAI2QIAIMxk4Bgit7dGwGXTWkNUpCH\nnVNtJ+Pf4v59ZqlJidtnbcO58KkXuYtWY+LGy76zRknFYztJT5Dchgg7XBsllGzV\nFfC4Ovv6nXEQ/UshO/1oJMOo2ew/b19Xxp0hYuh0HqrIBoHB
# ...

# %% [markdown]
# Languages used:

# %%
response_lang = requests.get('https://api.github.com/repos/ta-data-par/DAFT_NOV_21_01/languages')
response_lang.status_code
# Out:
# 200

# %%
response_lang.json()
# Out:
# {'Jupyter Notebook': 2722289, 'Python': 9907}

# %%
languages = []
for key in response_lang.json():
	languages.append(key)

# %%
print(languages)
# Out:
# ['Jupyter Notebook', 'Python']

# %% [markdown]
# ### Challange 1: Get a picture

# %%
import requests
r = requests.get('https://xkcd.com/1957')

# %%
r
# Out:
# <Response [200]>

# %%
r.headers
# Out:
# {'Connection': 'keep-alive', 'Content-Length': '2645', 'Server': 'nginx', 'Content-Type': 'text/html; charset=UTF-8', 'Last-Modified': 'Mon, 06 Dec 2021 05:00:04 GMT', 'ETag': 'W/"61ad98d4-1ace"', 'Expires': 'Mon, 06 Dec 2021 18:19:03 GMT', 'Cache-Control': 'max-age=300', 'Content-Encoding': 'gzip', 'Accept-Ranges': 'bytes', 'Date': 'Mon, 06 Dec 2021 18:14:04 GMT', 'Via': '1.1 varnish', 'Age': '0', 'X-Served-By': 'cache-cdg20739-CDG', 'X-Cache': 'MISS', 'X-Cache-Hits': '0', 'X-Timer': 'S1638814444.770296,VS0,VE431', 'Vary': 'Accept-Encoding'}

# %%
r.headers['Expires']
# Out:
# 'Mon, 06 Dec 2021 18:19:03 GMT'

# %%
r.text
# Out:
# '<!DOCTYPE html>\n<html>\n<head>\n<link rel="stylesheet" type="text/css" href="/s/7d94e0.css" title="Default"/>\n<title>xkcd: 2018 CVE List</title>\n<meta http-equiv="X-UA-Compatible" content="IE=edge"/>\n<link rel="shortcut icon" href="/s/919f27.ico" type="image/x-icon"/>\n<link rel="icon" href="/s/919f27.ico" type="image/x-icon"/>\n<link rel="alternate" type="application/atom+xml" title="Atom 1.0" href="/atom.xml"/>\n<link rel="alternate" type="application/rss+xml" title="RSS 2.0" href="/rss.xml"/>\n<script type="text/javascript" src="/s/b66ed7.js" async></script>\n<script type="text/javascript" src="/s/1b9456.js" async></script>\n\n<meta property="og:site_name" content="xkcd">\n\n<meta property="og:title" content="2018 CVE List">\n<meta property="og:url" content="https://xkcd.com/1957/">\n<meta property="og:image" content="https://imgs.xkcd.com/comics/2018_cve_list_2x.png">\n<meta name="twitter:card" content="summary_large_image">\n\n</head>\n<body>\n<div id="topContainer">\n<div 
# ...

# %%
recive = requests.get('https://imgs.xkcd.com/comics/number_of_computers.png')
with open(r'C:\Users\radek\IronHack\IronRadek\Week2\Day1\image.png', 'wb') as f:
    f.write(recive.content)

# %% [markdown]
# ### Challenge 2: Get the password

# %%
r = requests.get('https://httpbin.org/get')

# %%
r
# Out:
# <Response [200]>

# %%
r.headers
# Out:
# {'Date': 'Mon, 06 Dec 2021 18:14:24 GMT', 'Content-Type': 'application/json', 'Content-Length': '310', 'Connection': 'keep-alive', 'Server': 'gunicorn/19.9.0', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true'}

# %%
ploads = {'things1':2,'total1':25}
r = requests.get('https://httpbin.org/get',params= ploads)
print(r.text)
print(r.url)
# Out:
# {
#   "args": {
#     "things1": "2",
#     "total1": "25"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate, br",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.26.0",
#     "X-Amzn-Trace-Id": "Root=1-61ae5309-530c9e9749f043d811a7b628"
#   },
#   "origin": "78.115.16.38",
#   "url": "https://httpbin.org/get?things1=2&total1=25"
# }
#
# https://httpbin.org/get?things1=2&total1=25

# %%
pload = {'username' : 'Radek', 'password': 'admin'}
r = requests.post('https://httpbin.org/post', data = pload)
print(r.text)
# Out:
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "password": "admin",
#     "username": "Radek"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate, br",
#     "Content-Length": "29",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.26.0",
#     "X-Amzn-Trace-Id": "Root=1-61ae530c-0062df2c2ea6ea791044e9bd"
#   },
#   "json": null,
#   "origin": "78.115.16.38",
#   "url": "https://httpbin.org/post"
# }

# %%
pload = {'username' : 'Radek', 'password': 'admin'}
r = requests.post('https://httpbin.org/post', data = pload)
r_dictionary = r.json()
print(r_dictionary['form'])
# Out:
# {'password': 'admin', 'username': 'Radek'}

# %% [markdown]
# ### Challenge 3: Hidden Cold Joke

# %%
response = requests.get('https://api.github.com/search/code?q=.scavengerhunt in:path+repo:ironhack-datalabs/scavenger');
search = response.json()
search
# Out:
# {'total_count': 24,
#  'incomplete_results': False,
#  'items': [{'name': '.0016.scavengerhunt',
#    'path': '47222/.0016.scavengerhunt',
#    'sha': 'f5cb13223fdc1b11f4cfbbe1694f533b3c579fa0',
#    'url': 'https://api.github.com/repositories/162375181/contents/47222/.0016.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476',
#    'git_url': 'https://api.github.com/repositories/162375181/git/blobs/f5cb13223fdc1b11f4cfbbe1694f533b3c579fa0',
#    'html_url': 'https://github.com/ironhack-datalabs/scavenger/blob/9308ccc8a4c34c5e3a991ee815222a9691c32476/47222/.0016.scavengerhunt',
#    'repository': {'id': 162375181,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=',
#     'name': 'scavenger',
#     'full_name': 'ironhack-datalabs/scavenger',
#     'private': False,
#     'owner': {'login': 'ironhack-datalabs',
#      'id': 44225188,
#      'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ0MjI1MTg4',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/44225188?v=4',
# ...

# %%
files = search['items'];
files = sorted(files, key=lambda file: file['name']);

# %%
contents_list = []
headers = {'Accept': 'application/vnd.github.v3.raw', };
headers
# Out:
# {'Accept': 'application/vnd.github.v3.raw'}

# %%
for file in files:
    content_path = ('https://api.github.com/repos/ironhack-datalabs/scavenger/contents/{}').format(file['path']);
    response = requests.get(content_path, headers=headers);
    contents_list.append(response.text);

# %%
print(contents_list)
# Out:
# ['In\n', 'data\n', 'science,\n', '80\n', 'percent\n', 'of\n', 'time\n', 'spent\n', 'is\n', 'preparing\n', 'data,\n', '20\n', 'percent\n', 'of\n', 'time\n', 'is\n', 'spent\n', 'complaining\n', 'about\n', 'the\n', 'need\n', 'to\n', 'prepare\n', 'data.\n']

# %%
clean_contents = [word.strip('\n') for word in contents_list]
joke = " ".join(clean_contents);

# %%
joke
# Out:
# 'In data science, 80 percent of time spent is preparing data, 20 percent of time is spent complaining about the need to prepare data.'

# %% [markdown]
# Another aproach

# %%
# req_2 = requests.get('https://api.github.com/search/code?q=extension:json+repo:lemrod/vscode-b24')
#req_2 = requests.get('https://api.github.com/search/code?q=extension:scavengerhunt+repo:ironhack-datalabs/scavenger')
req_2 = requests.get('https://api.github.com/search/code?q=.scavengerhunt+in:path+repo:ironhack-datalabs/scavenger')
search = req_2.json()
search
# ironhack-datalabs/scavenger
# Out:
# {'total_count': 24,
#  'incomplete_results': False,
#  'items': [{'name': '.0016.scavengerhunt',
#    'path': '47222/.0016.scavengerhunt',
#    'sha': 'f5cb13223fdc1b11f4cfbbe1694f533b3c579fa0',
#    'url': 'https://api.github.com/repositories/162375181/contents/47222/.0016.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476',
#    'git_url': 'https://api.github.com/repositories/162375181/git/blobs/f5cb13223fdc1b11f4cfbbe1694f533b3c579fa0',
#    'html_url': 'https://github.com/ironhack-datalabs/scavenger/blob/9308ccc8a4c34c5e3a991ee815222a9691c32476/47222/.0016.scavengerhunt',
#    'repository': {'id': 162375181,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=',
#     'name': 'scavenger',
#     'full_name': 'ironhack-datalabs/scavenger',
#     'private': False,
#     'owner': {'login': 'ironhack-datalabs',
#      'id': 44225188,
#      'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ0MjI1MTg4',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/44225188?v=4',
# ...

# %%
files = flat['items']
# Out:
# 3

# %%
results = req_2.json()
flattened_data = pd.json_normalize(results)

req_2.headers
# Out:
# {'Server': 'GitHub.com', 'Date': 'Tue, 07 Dec 2021 10:58:02 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Cache-Control': 'no-cache', 'Vary': 'Accept, Accept-Encoding, Accept, X-Requested-With', 'X-GitHub-Media-Type': 'github.v3; format=json', 'Access-Control-Expose-Headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Used, X-RateLimit-Resource, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type, Deprecation, Sunset', 'Access-Control-Allow-Origin': '*', 'Strict-Transport-Security': 'max-age=31536000; includeSubdomains; preload', 'X-Frame-Options': 'deny', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '0', 'Referrer-Policy': 'origin-when-cross-origin, strict-origin-when-cross-origin', 'Content-Security-Policy': "default-src 'none'", 'Content-Encoding': 'gzip', 'X-RateLimit-Limit': '10', 'X-RateLimit-Remaining': '9', 'X-RateLimit-Reset': '1638874742', 'X-Rat
# ...

# %%
len(results['items'])
# Out:
# 24

# %%
data = pd.DataFrame(results['items'])
data_sorted = data.sort_values(by=['name'])
data_sorted
# Out:
#                    name                       path  \
# 10  .0001.scavengerhunt  98750/.0001.scavengerhunt
# 5   .0002.scavengerhunt  88596/.0002.scavengerhunt
# 18  .0003.scavengerhunt  60224/.0003.scavengerhunt
# 21  .0004.scavengerhunt  68848/.0004.scavengerhunt
# 13  .0005.scavengerhunt  44639/.0005.scavengerhunt
# 7   .0006.scavengerhunt  15024/.0006.scavengerhunt
# 17  .0007.scavengerhunt  17020/.0007.scavengerhunt
# 23  .0008.scavengerhunt  15534/.0008.scavengerhunt
# 1   .0009.scavengerhunt  97881/.0009.scavengerhunt
# 20  .0010.scavengerhunt  47830/.0010.scavengerhunt
# 6   .0011.scavengerhunt  50896/.0011.scavengerhunt
# 9   .0012.scavengerhunt  15534/.0012.scavengerhunt
# 12  .0013.scavengerhunt  89338/.0013.scavengerhunt
# 8   .0014.scavengerhunt  49418/.0014.scavengerhunt
# 16  .0015.scavengerhunt  91701/.0015.scavengerhunt
# 0   .0016.scavengerhunt  47222/.0016.scavengerhunt
# 22  .0017.scavengerhunt  70985/.0017.scavengerhunt
# ...

# %%
file_content = requests.get('https://api.github.com/repos/ironhack-datalabs/scavenger/contents/98750/.0001.scavengerhunt')
file_content.json()
# Out:
# {'name': '.0001.scavengerhunt',
#  'path': '98750/.0001.scavengerhunt',
#  'sha': '2add7632f1323136324efbf38ec66db1838b6173',
#  'size': 3,
#  'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/98750/.0001.scavengerhunt?ref=master',
#  'html_url': 'https://github.com/ironhack-datalabs/scavenger/blob/master/98750/.0001.scavengerhunt',
#  'git_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/2add7632f1323136324efbf38ec66db1838b6173',
#  'download_url': 'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/98750/.0001.scavengerhunt',
#  'type': 'file',
#  'content': 'SW4K\n',
#  'encoding': 'base64',
#  '_links': {'self': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/98750/.0001.scavengerhunt?ref=master',
#   'git': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/2add7632f1323136324efbf38ec66db1838b6173',
# ...

# %%
file_con_json = file_content.json()
s= file_con_json['content']
s
# Out:
# 'ZGF0YS4K\n'

# %%
for path in data_sorted['path']:
	print(path)
# Out:
# 98750/.0001.scavengerhunt
# 88596/.0002.scavengerhunt
# 60224/.0003.scavengerhunt
# 68848/.0004.scavengerhunt
# 44639/.0005.scavengerhunt
# 15024/.0006.scavengerhunt
# 17020/.0007.scavengerhunt
# 15534/.0008.scavengerhunt
# 97881/.0009.scavengerhunt
# 47830/.0010.scavengerhunt
# 50896/.0011.scavengerhunt
# 15534/.0012.scavengerhunt
# 89338/.0013.scavengerhunt
# 49418/.0014.scavengerhunt
# 91701/.0015.scavengerhunt
# 47222/.0016.scavengerhunt
# 70985/.0017.scavengerhunt
# 45525/.0018.scavengerhunt
# 70751/.0019.scavengerhunt
# 55685/.0020.scavengerhunt
# 30351/.0021.scavengerhunt
# 40303/.0022.scavengerhunt
# 55417/.0023.scavengerhunt
# 47222/.0024.scavengerhunt

# %%
#This GitHub API page provides the full reference. The API endpoint for reading a file:
#https://api.github.com/repos/{username}/{repository_name}/contents/{file_path}
answer_coded = []
for path in data_sorted['path']:
	file_content = requests.get(f'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/{path}')
	file_con_json = file_content.json()
	answer_coded.append(file_con_json['content'])

# %%
answer_coded
# Out:
# ['SW4K\n',
#  'ZGF0YQo=\n',
#  'c2NpZW5jZSwK\n',
#  'ODAK\n',
#  'cGVyY2VudAo=\n',
#  'b2YK\n',
#  'dGltZQo=\n',
#  'c3BlbnQK\n',
#  'aXMK\n',
#  'cHJlcGFyaW5nCg==\n',
#  'ZGF0YSwK\n',
#  'MjAK\n',
#  'cGVyY2VudAo=\n',
#  'b2YK\n',
#  'dGltZQo=\n',
#  'aXMK\n',
#  'c3BlbnQK\n',
#  'Y29tcGxhaW5pbmcK\n',
#  'YWJvdXQK\n',
#  'dGhlCg==\n',
#  'bmVlZAo=\n',
#  'dG8K\n',
#  'cHJlcGFyZQo=\n',
#  'ZGF0YS4K\n']

# %%
answer = ''
for item in answer_coded:
	answer += item.strip('\n')

answer = ''.join(answer_coded)
answer
# Out:
# 'SW4K\nZGF0YQo=\nc2NpZW5jZSwK\nODAK\ncGVyY2VudAo=\nb2YK\ndGltZQo=\nc3BlbnQK\naXMK\ncHJlcGFyaW5nCg==\nZGF0YSwK\nMjAK\ncGVyY2VudAo=\nb2YK\ndGltZQo=\naXMK\nc3BlbnQK\nY29tcGxhaW5pbmcK\nYWJvdXQK\ndGhlCg==\nbmVlZAo=\ndG8K\ncHJlcGFyZQo=\nZGF0YS4K\n'

# %%
import base64

# %%
joke = ''
for word in answer_coded:
	answer_bytes = word.encode('ascii')
	messegae_bytes =base64.b64decode(answer_bytes)
	message = messegae_bytes.decode('ascii')
	joke += message.strip('\n') + ' '
	#print(message)
print(joke)
# Out:
# In data science, 80 percent of time spent is preparing data, 20 percent of time is spent complaining about the need to prepare data.

# %%
joke.rstrip(' ')
# Out:
# 'In data science, 80 percent of time spent is preparing data, 20 percent of time is spent complaining about the need to prepare data.'
